# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("gender_classification.csv")

# %%
data
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
data.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# ...

# %%
data1=data.drop("gender",axis=1)
data1.corr()
# Out:
#                            long_hair  forehead_width_cm  forehead_height_cm  \
# long_hair                   1.000000          -0.006530           -0.017233
# forehead_width_cm          -0.006530           1.000000            0.088596
# forehead_height_cm         -0.017233           0.088596            1.000000
# nose_wide                   0.001216           0.251648            0.211655
# nose_long                   0.014432           0.257368            0.194120
# lips_thin                   0.011287           0.258564            0.205441
# distance_nose_to_lip_long  -0.025794           0.251328            0.215292
#
#                            nose_wide  nose_long  lips_thin  \
# long_hair                   0.001216   0.014432   0.011287
# forehead_width_cm           0.251648   0.257368   0.258564
# forehead_height_cm          0.211655   0.194120   0.205441
# nose_wide                   1.000000   0.565192   0.557615
# nose_long                   0.565192   1.000000   0.561229
# ...

# %%
f, ax = plt.subplots(figsize = (12,10))
sns.heatmap(data1.corr(), annot = True, linewidths = 0.5, linecolor = "blue", fmt = ".4f", ax = ax)
plt.show()

# %%
sns.pairplot(data, hue = "gender")
# Out:
# c:\Users\OMEN 0136AX\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\OMEN 0136AX\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# c:\Users\OMEN 0136AX\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# ...

# %%
data.columns
# Out:
# Index(['long_hair', 'forehead_width_cm', 'forehead_height_cm', 'nose_wide',
#        'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'gender'],
#       dtype='object')

# %%
sns.countplot(x = "gender", data = data)
data.loc[:,"gender"].value_counts()
# Out:
# gender
# Female    2501
# Male      2500
# Name: count, dtype: int64

# %%
Male = data[data.gender == "Male"].iloc[:100,:]
Female = data[data.gender == "Female"].iloc[:100,:]

plt.figure(figsize = (8,8))
plt.scatter(Male.forehead_height_cm, Male.forehead_width_cm, color = "blue", label = "Male", linewidths = 0.5, edgecolor = "black")
plt.scatter(Female.forehead_height_cm, Female.forehead_width_cm, color = "pink", label = "Male", linewidths = 0.5, edgecolor = "black")
plt.xlabel("forehead_height_cm")
plt.ylabel("forehead_width_cm")
plt.legend()
plt.show()

# %%
data_nbc = pd.read_csv("./gender_classification.csv")
data_nbc
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
# ...

# %%
x_data = data_nbc.drop(["gender"],axis = 1)
y_data = data_nbc.gender.values

# %%
x_data
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long
# ...

# %%
y_data
# Out:
# array(['Male', 'Female', 'Male', ..., 'Female', 'Female', 'Male'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.3, random_state=1)

# %% [markdown]
# Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()

gnb.fit(x_train, y_train)

print("print Train for accuracy of NBC algo: ", gnb.score(x_train,y_train))
print("print Test for accuracy of NBC algo: ", gnb.score(x_test,y_test))
# Out:
# print Train for accuracy of NBC algo:  0.97
# print Test for accuracy of NBC algo:  0.9713524317121919

# %% [markdown]
# Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()

mnb.fit(x_train, y_train)

print("print Train for accuracy of NBC algo: ", mnb.score(x_train,y_train))
print("print Test for accuracy of NBC algo: ", mnb.score(x_test,y_test))
# Out:
# print Train for accuracy of NBC algo:  0.9565714285714285
# print Test for accuracy of NBC algo:  0.960692871419054

# %% [markdown]
# Bernouli Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB
bnb = BernoulliNB()

bnb.fit(x_train, y_train)

print("print Train for accuracy of NBC algo: ", bnb.score(x_train,y_train))
print("print Test for accuracy of NBC algo: ", bnb.score(x_test,y_test))
# Out:
# print Train for accuracy of NBC algo:  0.9585714285714285
# print Test for accuracy of NBC algo:  0.9640239840106596

# %%
import pandas as pd

def create_frequency_table(data, features, target):
    """
    Creates a frequency table for a given dataset.

    Args:
        data: A Pandas DataFrame containing the dataset.
        features: A list of feature names.
        target: The name of the target variable (optional).

    Returns:
        A Pandas DataFrame representing the frequency table.

    Raises:
        ValueError: If the target variable is not specified for categorical features.
    """

    # Handle categorical features
    if data[features].dtypes.all() == object:
        if target is None:
            raise ValueError("Target variable is required for categorical features.")
        table = pd.crosstab(data[features], data[target])
        table.rename_axis(['Feature Value'], axis=1, inplace=True)
        table.rename_axis('Class', axis=0, inplace=True)
    # Handle numerical features (assuming counts or frequencies)
    else:
        table = data[features].describe(include='all')
        table = table.unstack().fillna(0)  # Fill missing values with 0s

    return table

# %%
def calculate_likelihood(frequency_table, feature, feature_value, target_class):
    """
    Calculates the likelihood of a feature-value combination for a specific class.

    Args:
        frequency_table: A Pandas DataFrame representing the frequency table.
        feature: The feature name.
        feature_value: The value of the feature.
        target_class: The target class.

    Returns:
        The likelihood of the feature-value combination.
    """

    count = frequency_table.loc[target_class, feature_value]
    total = frequency_table.loc[target_class].sum()
    return count / total if total > 0 else 0

# %%
features=['long_hair','forehead_width_cm','forehead_height_cm','nose_wide','nose_long','lips_thin','distance_nose_to_lip_long']

# %%
frequency_table = create_frequency_table(data, features, 'gender')
print(frequency_table)
# Out:
# long_hair                  count    5001.000000
#                            mean        0.869626
#                            std         0.336748
#                            min         0.000000
#                            25%         1.000000
#                            50%         1.000000
#                            75%         1.000000
#                            max         1.000000
# forehead_width_cm          count    5001.000000
#                            mean       13.181484
#                            std         1.107128
#                            min        11.400000
#                            25%        12.200000
#                            50%        13.100000
#                            75%        14.000000
#                            max        15.500000
# forehead_height_cm         count    5001.000000
#                            mean        5.946311
#                            std         0.541268
#                            min         5.100000
# ...

# %%
frequency_table = calculate_likelihood(frequency_table, data, features, 'gender')
print(frequency_table)
